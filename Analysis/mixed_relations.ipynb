# %%
import plotly.express as px
import pandas as pd

# %%
df = pd.read_csv("futuristic_city_traffic_sampled.csv")
df
# Out:
#               City        Vehicle Type      Weather Economic Condition  \
# 0        Ecoopolis               Drone        Clear            Booming
# 1        TechHaven  Autonomous Vehicle  Solar Flare             Stable
# 2      MetropolisX  Autonomous Vehicle        Clear             Stable
# 3      MetropolisX  Autonomous Vehicle        Rainy             Stable
# 4      MetropolisX  Autonomous Vehicle        Snowy          Recession
# ...            ...                 ...          ...                ...
# 11995  MetropolisX  Autonomous Vehicle        Rainy          Recession
# 11996    Ecoopolis  Autonomous Vehicle  Solar Flare          Recession
# 11997  MetropolisX  Autonomous Vehicle        Snowy            Booming
# 11998  MetropolisX  Autonomous Vehicle        Snowy          Recession
# 11999    Ecoopolis                 Car        Snowy          Recession
#
#       Day Of Week  Hour Of Day    Speed  Is Peak Hour  Random Event Occurred  \
# 0        Thursday           23  45.8742             0                      0
# 1          Monday            8  43.4756             1                      0
# 2          Monday           14  66.3621             0                      0
# 3        Thursday           15  46.4420             0                      0
# 4        Thursday            5  42.2895             0                      0
# ...           ...          ...      ...           ...                    ...
# 11995     Tuesday           11  69.6072             0                      0
# 11996      Monday           20  19.0563             0                      0
# 11997   Wednesday           20  25.2339             0                      0
# 11998    Thursday           12  93.4139             0                      0
# 11999   Wednesday           23  73.3337             0                      0
#
#        Energy Consumption  Traffic Density
# 0                 22.9371           0.1965
# 1                 43.9147           0.2234
# 2                 60.3292           0.3949
# 3                 44.4421           0.4116
# 4                 40.4684           0.0897
# ...                   ...              ...
# 11995             66.6097           0.3314
# 11996             16.9389           0.0811
# 11997             24.3912           0.6408
# 11998             89.3913           0.1717
# 11999             73.3337           0.0664
#
# [12000 rows x 11 columns]

# %%
fig = px.pie(df, names='Day Of Week', title='Traffic Distribution by Day of the Week')
fig.show()

# %%
fig = px.scatter(df.sample(5000), x="Speed", y="Energy Consumption",
                 animation_frame="Hour Of Day", animation_group="City",
                 size="Traffic Density", color="City",
                 title="Animated Scatter: Hourly Speed vs Energy")
fig.show()

# %%
fig = px.line(df.groupby(["Day Of Week","City"])["Speed"].mean().reset_index(),
              x="Day Of Week", y="Speed", color="City", title="City wise Avg Speed across Days")
fig.show()

# %%
fig = px.bar(df.groupby("Weather")["Random Event Occurred"].mean().reset_index(),
             x="Weather", y="Random Event Occurred", title="Random Events % by Weather")
fig.show()

# %%
fig = px.density_heatmap(df, x="Hour Of Day", y="Day Of Week", z="Traffic Density",
                         title="Day vs Hour vs Traffic Density")
fig.show()

# %%
fig = px.treemap(df, path=["City", "Day Of Week"], values="Traffic Density",
                 title="Traffic Density Treemap")
fig.show()

# %%
fig = px.sunburst(df, path=["Economic Condition", "Vehicle Type"], title="Sunburst: Economic Condition & Vehicle Type")
fig.show()
